# %% [markdown]
# <a href="https://colab.research.google.com/github/GsusLara/pythonPandasBasic/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('AC128125.xls',header = 25)
df.head()
# Out:
#   Activo Fijo  Estado Activo  Unnamed: 2  Unnamed: 3 Ubicación Responsable  \
# 0  EM00080650            4.0         NaN         NaN    L-1-12       CDFOD
# 1  EM00080573            4.0         NaN         NaN    L-1-12       CDFOD
# 2  EM00114536            4.0         NaN         NaN    L-1-12       CDFOD
# 3  EM00114532            4.0         NaN         NaN    L-1-12       CDFOD
# 4  EM00114527            4.0         NaN         NaN    L-1-12       CDFOD
#
#    Unnamed: 6     Placa Número Serie  Unnamed: 9  Unnamed: 10  \
# 0         NaN  279712.0   5CD6222R0Q         NaN          NaN
# 1         NaN  279733.0   5CD6222QZH         NaN          NaN
# 2         NaN  280452.0   5CD6222QFN         NaN          NaN
# 3         NaN  280455.0   5CD6223C6B         NaN          NaN
# 4         NaN  280463.0   5CD6222QF0         NaN          NaN
#
#                   Descripción                             Cartel Unnamed: 13  \
# ...

# %%
df.columns
# Out:
# Index(['Activo Fijo', 'Estado Activo', 'Unnamed: 2', 'Unnamed: 3', 'Ubicación',
#        'Responsable', 'Unnamed: 6', 'Placa', 'Número Serie', 'Unnamed: 9',
#        'Unnamed: 10', 'Descripción', 'Cartel', 'Unnamed: 13', 'Modalidad',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Acción AF',
#        'Estado Acción'],
#       dtype='object')

# %%
df[['Descripción','Placa','Número Serie']]
df
# Out:
#        Activo Fijo  Estado Activo  Unnamed: 2  Unnamed: 3 Ubicación  \
# 0       EM00080650            4.0         NaN         NaN    L-1-12
# 1       EM00080573            4.0         NaN         NaN    L-1-12
# 2       EM00114536            4.0         NaN         NaN    L-1-12
# 3       EM00114532            4.0         NaN         NaN    L-1-12
# 4       EM00114527            4.0         NaN         NaN    L-1-12
# ..             ...            ...         ...         ...       ...
# 90      EM00108698            4.0         NaN         NaN    L-1-12
# 91      EM00108585            4.0         NaN         NaN    L-1-12
# 92      EM00109810            4.0         NaN         NaN    L-1-12
# 93             NaN            NaN         NaN         NaN       NaN
# 94  Entregado por:            NaN         NaN         NaN       NaN
#
#    Responsable  Unnamed: 6     Placa Número Serie  Unnamed: 9  Unnamed: 10  \
# ...

# %%
df = df[['Descripción','Placa','Número Serie']]
df = df.iloc[:-2]
df
# Out:
#                    Descripción     Placa Número Serie
# 0   Portatil HP ProBook 440 G3  279712.0   5CD6222R0Q
# 1   Portatil HP ProBook 440 G3  279733.0   5CD6222QZH
# 2   Portatil HP ProBook 440 G3  280452.0   5CD6222QFN
# 3   Portatil HP ProBook 440 G3  280455.0   5CD6223C6B
# 4   Portatil HP ProBook 440 G3  280463.0   5CD6222QF0
# ..                         ...       ...          ...
# 88  Portatil HP ProBook 440 G3  340121.0   5CD72551HB
# 89  Portatil HP ProBook 440 G3  340647.0   5CD725509K
# 90  Portatil HP ProBook 440 G3  342718.0   5CD7312WRG
# 91  Portátil HP ProBook 440 G3  343080.0   5CD7312WZX
# 92  Portatil HP ProBook 440 G3  344722.0   5CD74034MJ
#
# [93 rows x 3 columns]

# %%
df['Placa'] = df['Placa'].astype(int)
descripcion = list(df['Descripción'])
placa = list(df['Placa'])
serie = list(df['Número Serie'])
salida = list(zip(descripcion, placa, serie))
salida
# Out:
# [('Portatil HP ProBook 440 G3', 279712, '5CD6222R0Q'),
#  ('Portatil HP ProBook 440 G3', 279733, '5CD6222QZH'),
#  ('Portatil HP ProBook 440 G3', 280452, '5CD6222QFN'),
#  ('Portatil HP ProBook 440 G3', 280455, '5CD6223C6B'),
#  ('Portatil HP ProBook 440 G3', 280463, '5CD6222QF0'),
#  ('Portatil HP ProBook 440 G3', 280484, '5CD6222QCT'),
#  ('Portatil HP ProBook 440 G3', 280488, '5CD6222N72'),
#  ('Portatil HP ProBook 440 G3', 280512, '5CD6222QDC'),
#  ('Portatil HP ProBook 440 G3', 281129, '5CD62242Y2'),
#  ('Portatil HP ProBook 440 G3', 281238, '5CD62260TX'),
#  ('Portatil HP ProBook 440 G3', 281753, '5CD62242SV'),
#  ('Portatil HP ProBook 440 G3', 282456, '5CD62253L9'),
#  ('Portatil HP ProBook 440 G3', 283415, '5CD62017FP'),
#  ('Portatil HP ProBook 440 G3', 283911, '5CD6204BKX'),
#  ('Portatil HP ProBook 440 G3', 284853, '5CD6204BS9'),
#  ('Portatil HP ProBook 440 G3', 285609, '5CD6203QVV'),
#  ('Portatil HP ProBook 440 G3', 286378, '5CD62017FR'),
# ...

# %%
len(salida)
# Out:
# 93

# %%
salida[64]
# Out:
# ('Portatil HP ProBook 440 G3', 327603, '5CD7184K9W')

# %%
salida[23][0]
# Out:
# 'Portatil HP ProBook 440 G3'
